# %% [markdown]
# <h1>PROBLEM 1</h1>

# %%
import numpy as np

x = np.arange(-50, 50.1, 0.1)
y = 0.5 * x + 1

print("Array for x:")
print(x)

print("\nArray for y:")
print(y)
# Out:
# Array for x:
# [-50.  -49.9 -49.8 ...  49.8  49.9  50. ]
#
# Array for y:
# [-24.   -23.95 -23.9  ...  25.9   25.95  26.  ]

# %% [markdown]
# <h1>PROBLEM 2</h1>

# %%
function = np.column_stack((x, y)).reshape(1001, 2)
print(function)
# Out:
# [[-50.   -24.  ]
#  [-49.9  -23.95]
#  [-49.8  -23.9 ]
#  ...
#  [ 49.8   25.9 ]
#  [ 49.9   25.95]
#  [ 50.    26.  ]]

# %% [markdown]
# <h1>PROBLEM 3</h1>

# %%
def get_gradient(x, y):
    gradient = np.diff(y) / np.diff(x)
    return gradient

gradient = get_gradient(x, y)
print(gradient)
# Out:
# [0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
#  0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5
# ...

# %% [markdown]
# <h1>PROBLEM 4</h1>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(x, y, label='y = (1/2)x + 1')
plt.title('Linear Function')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 2)
plt.plot(x[:-1], gradient, label='Gradient')
plt.title('Gradient along x')
plt.xlabel('x')
plt.ylabel('Gradient')
plt.legend()

# %% [markdown]
# <h1>PROBLEM 5</h1>

# %%
def compute_gradient(function, x_range=(-50, 50.1, 0.1)):
    
    array_x = np.arange(*x_range)
    array_y = function(array_x)
    array_xy = np.column_stack((array_x, array_y))
    gradient = np.diff(array_y) / np.diff(array_x)
    return array_xy, gradient

def function1(array_x):
    return array_x**2

def function2(array_x):
    return 2 * array_x**2 + 2**array_x

def function3(array_x):
    return np.sin(np.sqrt(array_x))

# %%
array_xy1, gradient1 = compute_gradient(function1)
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.plot(array_xy1[:, 0], array_xy1[:, 1], label='y = x^2')
plt.title('Function 1: y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
print(f"Gradient for Function 1:{gradient1}")
# Out:
# Gradient for Function 1:[-99.9 -99.7 -99.5 -99.3 -99.1 -98.9 -98.7 -98.5 -98.3 -98.1 -97.9 -97.7
#  -97.5 -97.3 -97.1 -96.9 -96.7 -96.5 -96.3 -96.1 -95.9 -95.7 -95.5 -95.3
#  -95.1 -94.9 -94.7 -94.5 -94.3 -94.1 -93.9 -93.7 -93.5 -93.3 -93.1 -92.9
#  -92.7 -92.5 -92.3 -92.1 -91.9 -91.7 -91.5 -91.3 -91.1 -90.9 -90.7 -90.5
#  -90.3 -90.1 -89.9 -89.7 -89.5 -89.3 -89.1 -88.9 -88.7 -88.5 -88.3 -88.1
#  -87.9 -87.7 -87.5 -87.3 -87.1 -86.9 -86.7 -86.5 -86.3 -86.1 -85.9 -85.7
#  -85.5 -85.3 -85.1 -84.9 -84.7 -84.5 -84.3 -84.1 -83.9 -83.7 -83.5 -83.3
#  -83.1 -82.9 -82.7 -82.5 -82.3 -82.1 -81.9 -81.7 -81.5 -81.3 -81.1 -80.9
#  -80.7 -80.5 -80.3 -80.1 -79.9 -79.7 -79.5 -79.3 -79.1 -78.9 -78.7 -78.5
#  -78.3 -78.1 -77.9 -77.7 -77.5 -77.3 -77.1 -76.9 -76.7 -76.5 -76.3 -76.1
#  -75.9 -75.7 -75.5 -75.3 -75.1 -74.9 -74.7 -74.5 -74.3 -74.1 -73.9 -73.7
#  -73.5 -73.3 -73.1 -72.9 -72.7 -72.5 -72.3 -72.1 -71.9 -71.7 -71.5 -71.3
#  -71.1 -70.9 -70.7 -70.5 -70.3 -70.1 -69.9 -69.7 -69.5 -69.3 -69.1 -68.9
# ...

# %%
array_xy2, gradient2 = compute_gradient(function2)
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 2)
plt.plot(array_xy2[:, 0], array_xy2[:, 1], label='y = 2*x^2 + 2^x')
plt.title('Function 2: y = 2*x^2 + 2^x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
print(f"Gradient for Function 2:{gradient2}")
# Out:
# Gradient for Function 2:[-1.99800000e+02 -1.99400000e+02 -1.99000000e+02 -1.98600000e+02
#  -1.98200000e+02 -1.97800000e+02 -1.97400000e+02 -1.97000000e+02
#  -1.96600000e+02 -1.96200000e+02 -1.95800000e+02 -1.95400000e+02
#  -1.95000000e+02 -1.94600000e+02 -1.94200000e+02 -1.93800000e+02
#  -1.93400000e+02 -1.93000000e+02 -1.92600000e+02 -1.92200000e+02
#  -1.91800000e+02 -1.91400000e+02 -1.91000000e+02 -1.90600000e+02
#  -1.90200000e+02 -1.89800000e+02 -1.89400000e+02 -1.89000000e+02
#  -1.88600000e+02 -1.88200000e+02 -1.87800000e+02 -1.87400000e+02
#  -1.87000000e+02 -1.86600000e+02 -1.86200000e+02 -1.85800000e+02
#  -1.85400000e+02 -1.85000000e+02 -1.84600000e+02 -1.84200000e+02
#  -1.83800000e+02 -1.83400000e+02 -1.83000000e+02 -1.82600000e+02
#  -1.82200000e+02 -1.81800000e+02 -1.81400000e+02 -1.81000000e+02
#  -1.80600000e+02 -1.80200000e+02 -1.79800000e+02 -1.79400000e+02
#  -1.79000000e+02 -1.78600000e+02 -1.78200000e+02 -1.77800000e+02
# ...

# %%
array_xy3, gradient3 = compute_gradient(function3)
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 3)
plt.plot(array_xy3[:, 0], array_xy3[:, 1], label='y = sin(sqrt(x))')
plt.title('Function 3: y = sin(sqrt(x))')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
print(f"Gradient for Function 3:{gradient3}")
# Out:
# Gradient for Function 3:[            nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
# ...

# %% [markdown]
# <h1>PROBLEM 6</h1>

# %%
print(
f'''
function 1:
    - min: {array_xy1.min()}
    - argmin: {array_xy1.argmin()}
function 2:
    - min: {array_xy2.min()}
    - argmin: {array_xy2.argmin()}
function 3:
    - min: {array_xy3.min()}
    - argmin: {array_xy3.argmin()}
''')
# Out:
# function 1:
#     - min: -50.0
#     - argmin: 0
# function 2:
#     - min: -50.0
#     - argmin: 0
# function 3:
#     - min: nan
#     - argmin: 1
